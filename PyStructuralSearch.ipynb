# %%
import pandas as pd
import os
import ipywidgets as widgets
from IPython.display import display

# %%
partOfSpeech = {
    'n': 'noun',
    'v': 'verb',
    't': 'participle',
    'a': 'adjective',
    'd': 'adverb',
    'l': 'article',
    'g': 'particle',
    'c': 'conjunction',
    'r': 'preposition',
    'p': 'pronoun',
    'm': 'numeral',
    'i': 'interjection',
    'e': 'exclamation',
    'u': 'punctuation',
    'x': 'irregular',
    '-': 'null',
    
    #proiel POStags
    'A-': 'adjective',
    'Df': 'adverb',
    'S-': 'article',
    'Ma': 'cardinal numeral',
    'Nb': 'common noun',
    'C-': 'conjunction',
    'Pd': 'demonstrative pronoun',
    'F-': 'foreign word',
    'Px': 'indefinite pronoun',
    'N-': 'infinitive marker',
    'I-': 'interjection',
    'Du': 'interrogative adverb',
    'Pi': 'interrogative pronoun',
    'Mo': 'ordinal numeral',
    'Pp': 'personal pronoun',
    'Pk': 'personal reflexive pronoun',
    'Ps': 'possessive pronoun',
    'Pt': 'possessive reflexive pronoun',
    'R-': 'preposition',
    'Ne': 'proper noun',
    'Py': 'quantifier',
    'Pc': 'reciprocal pronoun',
    'Dq': 'relative adverb',
    'Pr': 'relative pronoun',
    'G-': 'subjunction',
    'V-': 'verb',
    'X-': 'unassigned'
}

person = {
    '1': 'first',
    '2': 'second',
    '3': 'third',
    '-': 'null',
    'x': 'uncertain'
}

number = {
      's': 'singular',
      'd': 'dual',
      'p': 'plural',
      '-': 'null',
      'x': 'uncertain'
}

tense = {
      'p': 'present',
      'i': 'imperfect',
      'r': 'perfect',
      'l': 'pluperfect',
      't': 'future perfect',
      'f': 'future',
      'a': 'aorist',
      '-': 'null',

      's': 'resultative',
      'u': 'past',
      'x': 'uncertain'
}

mood = {
      'i': 'indicative',
      's': 'subjunctive',
      'o': 'optative',
      'n': 'infinitive',
      'm': 'imperative',
      'p': 'participle',
      'd': 'gerund',
      'g': 'gerundive',
      '-': 'null',
      'u': 'supine',
      'x': 'uncertain mood',
      'y': 'finiteness unspecified',
      'e': 'indicative or subjunctive',
      'f': 'indicative or imperative',
      'h': 'subjunctive or imperative',
      't': 'finite',
      'x': 'uncertain'
}

voice = {
      'a': 'active',
      'p': 'passive',
      'm': 'middle',
      'e': 'middle-passive',
      '-': 'null',
      'x': 'uncertain'
}

gender = {
      'm': 'masculine',
      'f': 'feminine',
      'n': 'neuter',
      '-': 'null',
      'p': 'masculine or feminine',
      'o': 'masculine or neuter',
      'r': 'feminine or neuter',
      'q': 'masculine, feminine or neuter',
      'x': 'uncertain'
}

case = {
      'n': 'nominative',
      'g': 'genitive',
      'd': 'dative',
      'a': 'accusative',
      'v': 'vocative',
      'l': 'locative',
      '-': 'null',
      'o': 'oblique',
      'c': 'genitive or dative',
      'e': 'accusative or dative',
      'b': 'ablative',
      'i': 'instrumental',
      'z': 'no case',
      'x': 'uncertain'
}

degree = {
      'c': 'comparative',
      's': 'superlative',
      '-': 'null',
      'p': 'positive',
      'z': 'no degree',
      'x': 'uncertain'
}

strength = {
      'w': 'weak',
      's': 'strong',
      't': 'weak or strong',
      '-': 'null'
}

inflection = {
      'n': 'non-inflecting',
      'i': 'inflecting',
      '-': 'null'
}

# %%
partOfSpeech = {
    'noun'         : 'n'                                          
    'verb'         : 'v'                                          
    'participle'   : 't'                                                
    'adjective'    : 'a'                                                
    'adverb'       : 'd'                                          
    'article'      : 'l'                                                
    'particle'     : 'g'                                                
    'conjunction'  : 'c'                                                
    'preposition'  : 'r'                                                
    'pronoun'      : 'p'                                                
    'numeral'      : 'm'                                                
    'interjection' : 'i'                                                
    'exclamation'  : 'e'                                                
    'punctuation'  : 'u'                                                
    'irregular'    : 'x'                                                
    'null'         : '-'                                          
    
    #proiel POStags
    'adjective'                    : 'A-'                                
    'adverb'                       : 'Df'                                
    'article'                      : 'S-'                                
    'cardinal numeral'             : 'Ma'                                      
    'common noun'                  : 'Nb'                                
    'conjunction'                  : 'C-'                                
    'demonstrative pronoun'        : 'Pd'                                            
    'foreign word'                 : 'F-'                                      
    'indefinite pronoun'           : 'Px'                                            
    'infinitive marker'            : 'N-'                                      
    'interjection'                 : 'I-'                                      
    'interrogative adverb'         : 'Du'                                            
    'interrogative pronoun'        : 'Pi'                                            
    'ordinal numeral'              : 'Mo'                                      
    'personal pronoun'             : 'Pp'                                      
    'personal reflexive pronoun'   : 'Pk'                                                  
    'possessive pronoun'           : 'Ps'                                            
    'possessive reflexive pronoun' : 'Pt'                                                  
    'preposition'                  : 'R-'                                
    'proper noun'                  : 'Ne'                                
    'quantifier'                   : 'Py'                                
    'reciprocal pronoun'           : 'Pc'                                            
    'relative adverb'              : 'Dq'                                      
    'relative pronoun'             : 'Pr'                                      
    'subjunction'                  : 'G-'                                
    'verb'                         : 'V-'                          
    'unassigned'                   : 'X-' 
}

person = {
    'first'        : '1'                                          
    'second'       : '2'                                          
    'third'        : '3'                                          
    'null'         : '-'                                          
    'uncertain'    : 'x'
}

number = {
      'singular'                     : 's'                         
      'dual'                         : 'd'                   
      'plural'                       : 'p'                         
      'uncertain number'             : 'x'                               
}

tense = {
      'present'                      : 'p'                         
      'imperfect'                    : 'i'                         
      'perfect'                      : 'r'                         
      'pluperfect'                   : 'l'                         
      'future perfect'               : 't'                               
      'future'                       : 'f'                         
      'aorist'                       : 'a'                         
      'resultative'                  : 's'                               
      'past'                         : 'u'                   
      'uncertain tense'              : 'x'                               
}

mood = {
      'indicative'                   : 'i'                         
      'subjunctive'                  : 's'                               
      'optative'                     : 'o'                         
      'infinitive'                   : 'n'                         
      'imperative'                   : 'm'                         
      'participle'                   : 'p'                         
      'gerund'                       : 'd'                         
      'gerundive'                    : 'g'                         
      'supine'                       : 'u'                         
      'uncertain mood'               : 'x'                               
      'finiteness unspecified'       : 'y'                                     
      'indicative or subjunctive'    : 'e'                                           
      'indicative or imperative'     : 'f'                                           
      'subjunctive or imperative'    : 'h'                                           
      'finite'                       : 't'                         
      'uncertain mood'               : 'x'                               
}

voice = {
      'active'                       : 'a'                         
      'passive'                      : 'p'                         
      'middle'                       : 'm'                         
      'middle-passive'               : 'e'                               
      'null'                         : '-'                   
      'uncertain voice'              : 'x'                               
}

gender = {
      'masculine'                    : 'm'                         
      'feminine'                     : 'f'                         
      'neuter'                       : 'n'                         
      'null'                         : '-'                   
      'masculine or feminine'        : 'p'                                     
      'masculine or neuter'          : 'o'                                     
      'feminine or neuter'           : 'r'                                     
      'masculine feminine or neuter' : 'q'                                           
      'uncertain gender'             : 'x'                               
}

case = {
      'nominative'                   : 'n'                         
      'genitive'                     : 'g'                         
      'dative'                       : 'd'                         
      'accusative'                   : 'a'                         
      'vocative'                     : 'v'                         
      'locative'                     : 'l'                         
      'null'                         : '-'                   
      'oblique'                      : 'o'                         
      'genitive or dative'           : 'c'                                     
      'accusative or dative'         : 'e'                                     
      'ablative'                     : 'b'                         
      'instrumental'                 : 'i'                               
      'no case'                      : 'z'                         
      'uncertain case'               : 'x'                               
}

degree = {
      'comparative'                  : 'c'                               
      'superlative'                  : 's'                               
      'null degree'                  : '-'                   
      'positive'                     : 'p'                         
      'no degree'                    : 'z'                         
      'uncertain degree'             : 'x'                               
}

strength = {
      'weak'                         : 'w'                   
      'strong'                       : 's'                         
      'weak or strong'               : 't'                               
}

inflection = {
      'non-inflecting'               : 'n'                               
      'inflecting'                   : 'i'                         
}

keydict = {
    
}

# %%
# change ROOT to local root
#ROOT = "c:\\Users\\bella\\OneDrive\\Documents\\GitHub"
ROOT = "/Users/bellahwang/Documents/GitHub"

ALLAUTHORS = os.path.join(ROOT, 'treebankstats', 'allauthors.csv')

df = pd.read_csv(ALLAUTHORS, low_memory=False)

# %%
df
# Out:
#          Unnamed: 0     Author AuthorTLG WorkTLG  Timeline StartDate EndDate  \
# 0                 0  Aeschines   tlg0026  tlg001      -4.0      -389    -314
# 1                 1  Aeschines   tlg0026  tlg001      -4.0      -389    -314
# 2                 2  Aeschines   tlg0026  tlg001      -4.0      -389    -314
# 3                 3  Aeschines   tlg0026  tlg001      -4.0      -389    -314
# 4                 4  Aeschines   tlg0026  tlg001      -4.0      -389    -314
# ...             ...        ...       ...     ...       ...       ...     ...
# 1489840     1495803  Herodotus   tlg0016     NaN      -5.0     -484c   -425c
# 1489841     1495804  Herodotus   tlg0016     NaN      -5.0     -484c   -425c
# 1489842     1495805  Herodotus   tlg0016     NaN      -5.0     -484c   -425c
# 1489843     1495806  Herodotus   tlg0016     NaN      -5.0     -484c   -425c
# 1489844     1495807  Herodotus   tlg0016     NaN      -5.0     -484c   -425c
#
# ...

# %%
LEMMA = 'μῆνις'

df.loc[df['lemma'] == LEMMA]
# Out:
#          Unnamed: 0                      Author AuthorTLG WorkTLG  Timeline  \
# 117951       117951                   Athenaeus   tlg0008  tlg001       3.0
# 120424       120424                   Athenaeus   tlg0008  tlg001       3.0
# 268132       268132  Dionysius of Halicarnassus   tlg0081  tlg001      -1.0
# 729446       735409                      Lucian   tlg0062  tlg020       2.0
# 767712       773675                     Phlegon   tlg0585  tlg001       2.0
# ...             ...                         ...       ...     ...       ...
# 1478086     1484049                   Herodotus   tlg0016     NaN      -5.0
# 1478138     1484101                   Herodotus   tlg0016     NaN      -5.0
# 1478169     1484132                   Herodotus   tlg0016     NaN      -5.0
# 1485232     1491195                   Herodotus   tlg0016     NaN      -5.0
# 1488293     1494256                   Herodotus   tlg0016     NaN      -5.0
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
from enum import Enum

class Colour:

  def __init__(self, label, hex_value = "000000"):
    self.label = label
    self.hex_value = hex

  def __str__(self):
    return self.label

  def __hash__(self):
    hash(self.label)


class Colours(Enum):
  WHITE = Colour("White", "ffffff")
  BLACK = Colour("Black", "000000")

  def __repr__(self):
    return self.value

  def __str__(self):
    return str(self.value)

# %%
def myFUN_searchString(value, string):
    s = string.split(':')
    return value in s

def myFUN_search(value):
    s = value.split(':')
    df2 = df.loc[df['lemma'] == value]
    #df.loc[:,'Flag']=[myFUN_searchString(value,x) for x in t.loc[:,'string']]
    return df2

keyword = widgets.Text(
    placeholder='Type something (e.g. μῆνις)',
    description='keyword:',
    disabled=False
)
display(keyword)


button = widgets.Button(description="search")
display(button)

output = widgets.Output()

@output.capture()
def on_button_clicked(b):
    t1 = myFUN_search(keyword.value)
    display(t1)

button.on_click(on_button_clicked)
display(output)
# Out:
# Text(value='', description='keyword:', placeholder='Type something (e.g. μῆνις)')
# Button(description='search', style=ButtonStyle())
# Output()
